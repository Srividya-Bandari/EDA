# %% [markdown]
# **How to read Data**
#
# - location
#
# - file name
#
# - extension

# %%
# To read data from file which is same location that of python file location is not required to mintioned.

import pandas as pd

# %%
pd.read_csv('edaData2.csv')
# Out:
#     names  age     city job
# 0   vidya   20      hyd  DS
# 1  lalith   25  chennai  DE
# 2    jaya   21      blr  CS

# %%
pd.read_excel('edaDataexcel1.xlsx',engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.read_excel('edaDataexcel1.xlsx',engine='openpyxl')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
# ...

# %%
pd.read_csv(r'C:\Users\Owner\OneDrive\Documents\NareshIT\DataScience\DataFiles\Visadataset - Visadataset.csv')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.read_excel(r'C:\Users\Owner\OneDrive\Documents\NareshIT\DataScience\DataFiles\IMDB Dataset_sample.xlsx')
# Out:
#                                                  review sentiment
# 0     One of the other reviewers has mentioned that ...  positive
# 1     A wonderful little production. <br /><br />The...  positive
# 2     I thought this was a wonderful way to spend ti...  positive
# 3     Basically there's a family where a little boy ...  negative
# 4     Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                 ...       ...
# 1109  I have not read the book that this was based u...  positive
# 1110  Brilliant thriller, deserving far more fame, M...  positive
# 1111  I saw this movie a fews years ago and was lite...  positive
# 1112  I just watched this movie on Bravo! and it was...  negative
# 1113  How nice to have a movie the entire family can...  positive
#
# [1114 rows x 2 columns]

# %%
pd.read_csv(r'C:\Users\Owner\OneDrive\Documents\NareshIT\DataScience\DataFiles\bank - bank.csv')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# **Create Data Frame using dictionary**
#
# - keys beaomes columns
# - values becomes rows
# - no need to provide column names seperately

# %%
dict = {'Names': ['vidya','lalith','jaya'], 'age' :[25,24,23]}
pd.DataFrame(dict)
# Out:
#     Names  age
# 0   vidya   25
# 1  lalith   24
# 2    jaya   23

# %%
dict1 = {'vidya':25,
        'lalith':24,
        'jaya':23}
pd.DataFrame(dict1, index= [0])
# Out:
#    vidya  lalith  jaya
# 0     25      24    23
