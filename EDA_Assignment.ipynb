# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df = pd.read_csv(r"C:\Users\Owner\OneDrive\Documents\NareshIT\DataScience\DataFiles\Visadataset - Visadataset.csv")
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
visa_df.education_of_employee
# type(visa_df.education_of_employee)  ---> pandas.core.series.Series
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df.education_of_employee == "Master's"
# type(visa_df.education_of_employee == "Master's") ----> pandas.core.series.Series
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 25475    False
# 25476    False
# 25477     True
# 25478     True
# 25479    False
# Name: education_of_employee, Length: 25480, dtype: bool

# %%
visa_df[visa_df.education_of_employee == "Master's"]
# type(visa_df[visa_df.education_of_employee == "Master's"]) ----> pandas.core.frame.DataFrame
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 1         EZYV02           Asia              Master's                  Y
# 4         EZYV05         Africa              Master's                  Y
# 5         EZYV06           Asia              Master's                  Y
# 10        EZYV11           Asia              Master's                  N
# 14        EZYV15           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25467  EZYV25468  North America              Master's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
unqEdu = visa_df.education_of_employee.unique()
unqEdu
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
(len(visa_df[visa_df.education_of_employee == "High School"]),
len(visa_df[visa_df.education_of_employee == "Master's"]),
len(visa_df.education_of_employee == "Bachelor's"),
len(visa_df.education_of_employee == "Doctorate"))
# Out:
# (3420, 9634, 25480, 25480)

# %%
educnt = []
for edu in unqEdu:
    cnt = len(visa_df[visa_df.education_of_employee == edu])
    educnt.append(cnt)

education_df = pd.DataFrame(zip(unqEdu,educnt), columns=['name','cnt'])
education_df
# Out:
#           name    cnt
# 0  High School   3420
# 1     Master's   9634
# 2   Bachelor's  10234
# 3    Doctorate   2192

# %%
education_df.to_csv("education_df.csv",index=False)

# %%
edf = visa_df.education_of_employee.value_counts()

# %%
visa_df['education_of_employee'].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
visa_df.region_of_employment
# Out:
# 0             West
# 1        Northeast
# 2             West
# 3             West
# 4            South
#            ...
# 25475        South
# 25476    Northeast
# 25477        South
# 25478         West
# 25479      Midwest
# Name: region_of_employment, Length: 25480, dtype: object

# %%
unqReg = visa_df.region_of_employment.unique()
unqReg
# Out:
# array(['West', 'Northeast', 'South', 'Midwest', 'Island'], dtype=object)

# %%
visa_df.region_of_employment == "West"
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478     True
# 25479    False
# Name: region_of_employment, Length: 25480, dtype: bool

# %%
visa_df[visa_df.region_of_employment == "West"]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 15        EZYV16           Asia           High School                  Y
# ...          ...            ...                   ...                ...
# 25460  EZYV25461         Europe              Master's                  Y
# 25461  EZYV25462           Asia              Master's                  Y
# 25462  EZYV25463         Europe            Bachelor's                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
(len(visa_df[visa_df.region_of_employment == "West"]),
 len(visa_df[visa_df.region_of_employment == "Northeast"]),
 len(visa_df[visa_df.region_of_employment == "South"]),
 len(visa_df[visa_df.region_of_employment == "Midwest"]),
 len(visa_df[visa_df.region_of_employment == "Island"]))
# Out:
# (6586, 7195, 7017, 4307, 375)

# %%
regCnt = []
for reg in unqReg:
    cnt = len(visa_df[visa_df.region_of_employment == reg])
    regCnt.append(cnt)

pd.DataFrame(zip(unqReg, regCnt), columns= ['region', 'cnt'])
# Out:
#       region   cnt
# 0       West  6586
# 1  Northeast  7195
# 2      South  7017
# 3    Midwest  4307
# 4     Island   375
